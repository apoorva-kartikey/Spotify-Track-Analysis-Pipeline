# %%
# Spotify Track Popularity Analysis

## Data Cleaning

#This notebook focuses on understanding and preparing the Spotify dataset for analysis. The data cleaning process includes loading the dataset, examining its structure, identifying missing values, checking for duplicate records, and ensuring that the data is ready for exploratory analysis and machine learning.

# %%
# Import the libraries required for data analysis

import pandas as pd
import numpy as np

# %%
# Load the Spotify dataset

spotify_df = pd.read_csv(r"C:\Users\SUJATA\Desktop\Data\Data Science\data_cleaned.csv")

# %%
# Display the first five rows of the dataset

spotify_df.head()

# %%
# Display the number of rows and columns

print(f"Number of Rows    : {spotify_df.shape[0]}")
print(f"Number of Columns : {spotify_df.shape[1]}")

# %%
spotify_df.columns
spotify_df.info()

# %%
# Check the number of missing values in each column

spotify_df.isnull().sum()

# %%
# The dataset is already clean.
# A random sample of 10,000 records is selected for analysis.


spotify_sample = spotify_df.sample(n=10000, random_state=42)

# Reset the index for a clean dataset

spotify_sample.reset_index(drop=True, inplace=True)

# Save the sampled dataset

spotify_sample.to_csv(r"C:\Users\SUJATA\Desktop\Data\Data Science\spotify_sample_10000.csv", index=False)

print(f"Sample Dataset Shape   : {spotify_sample.shape}")

# Display the first five rows

spotify_sample.head()
